# %% [markdown]
# Задание 1

# %% [markdown]
# Импортируйте библиотеки pandas и numpy.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Загрузите "Boston House Prices dataset" из встроенных наборов данных библиотеки sklearn. Создайте датафреймы X и Y из этих данных.

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
# Out:
# /home/acseler/geek/python/pdsnmsl/env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
feature_names = boston.feature_names
feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
X = pd.DataFrame(boston.data, columns=feature_names)
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y = pd.DataFrame(boston.target, columns=['price'])
y.head()
# Out:
#    price
# 0   24.0
# 1   21.6
# 2   34.7
# 3   33.4
# 4   36.2

# %% [markdown]
# Разбейте эти датафреймы н а тренировочные (X_train, y_train) и тестовые (X_test, y_test) с помощью функции train_test_split так, чтобы размер тестовой выборки составлял 30% от всех данных, при этом аргумент random_state должен быть равен 42.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Создайте модель линейной регрессии под названием lr с помощью класса LinearRegression из модуля sklearn.linear_model.

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %% [markdown]
# Обучите модель на тренировочных данных (используйте все признаки) и сделайте предсказание на тестовых.

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
check_test = pd.DataFrame({'y_test': y_test['price'], 'y_pred': y_pred.flatten()}, columns=['y_test', 'y_pred'])
check_test
# Out:
#      y_test     y_pred
# 173    23.6  28.648960
# 274    32.4  36.495014
# 491    13.6  15.411193
# 72     22.8  25.403213
# 452    16.1  18.855280
# ..      ...        ...
# 441    17.1  17.403672
# 23     14.5  13.385941
# 225    50.0  39.983425
# 433    14.3  16.682863
# 447    12.6  18.285618
#
# [152 rows x 2 columns]

# %% [markdown]
# Вычислите R2 полученных предказаний с помощью r2_score из модуля sklearn.metrics.

# %%
from sklearn.metrics import r2_score

# %%
R2 = r2_score(y_test['price'], y_pred)
R2
# Out:
# 0.7112260057484974

# %% [markdown]
# Задание 2

# %% [markdown]
# Создайте модель под названием model с помощью RandomForestRegressor из модуля sklearn.ensemble. Сделайте агрумент n_estimators равным 1000,
# max_depth должен быть равен 12 и random_state сделайте равным 42.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=1000, max_depth=12, random_state=42)

# %% [markdown]
# Обучите модель на тренировочных данных аналогично тому, как вы обучали модель
#  LinearRegression,
# но при этом в метод fit вместо датафрейма y_train поставьте y_train.values[:, 0],
# чтобы получить из датафрейма одномерный массив Numpy,
# так как для класса RandomForestRegressor в данном методе для аргумента y предпочтительно применение массивов вместо датафрейма.
# Сделайте предсказание на тестовых данных и посчитайте R2. Сравните с результатом из предыдущего задания.
# Напишите в комментариях к коду, какая модель в данном случае работает лучше.

# %%
model.fit(X_train, y_train.values[:, 0])
# Out:
# RandomForestRegressor(max_depth=12, n_estimators=1000, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
check_test = pd.DataFrame({'y_test': y_test['price'], 'y_pred': y_pred.flatten()}, columns=['y_test', 'y_pred'])
check_test
# Out:
#      y_test     y_pred
# 173    23.6  22.806412
# 274    32.4  31.131464
# 491    13.6  16.339125
# 72     22.8  23.810726
# 452    16.1  17.139521
# ..      ...        ...
# 441    17.1  13.521640
# 23     14.5  15.112621
# 225    50.0  42.808700
# 433    14.3  15.586103
# 447    12.6  16.072425
#
# [152 rows x 2 columns]

# %%
R2 = r2_score(y_test['price'], y_pred)
R2
# Out:
# 0.87472606157312

# %% [markdown]
# В данном случае модель RandomForestRegressor работает лучше, т.к. значение R2 выше

# %% [markdown]
# *Задание 3

# %% [markdown]
# Вызовите документацию для класса RandomForestRegressor,
# найдите информацию об атрибуте feature_importances_.
# С помощью этого атрибута найдите сумму всех показателей важности,
# установите, какие два признака показывают наибольшую важность.

# %%
RandomForestRegressor?
# Out:
# Init signature:
# RandomForestRegressor(
#     n_estimators=100,
#     *,
#     criterion='squared_error',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features='auto',
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     bootstrap=True,
#     oob_score=False,
#     n_jobs=None,
#     random_state=None,
#     verbose=0,
#     warm_start=False,
#     ccp_alpha=0.0,
#     max_samples=None,
# )
# Docstring:
# A random forest regressor.
#
# A random forest is a meta estimator that fits a number of classifying
# decision trees on various sub-samples of the dataset and uses averaging
# to improve the predictive accuracy and control over-fitting.
# The sub-sample size is controlled with the `max_samples` parameter if
# `bootstrap=True` (default), otherwise the whole dataset is used to build
# each tree.
#
# Read more in the :ref:`User Guide <forest>`.
#
# Parameters
# ----------
# ...

# %%
model.feature_importances_
# Out:
# array([0.03167574, 0.00154252, 0.00713813, 0.00123624, 0.01426897,
#        0.40268179, 0.01429864, 0.06397257, 0.00528122, 0.01152493,
#        0.01808108, 0.01245085, 0.41584732])

# %%
model.feature_names_in_
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype=object)

# %%
np.sum(model.feature_importances_)
# Out:
# 1.0

# %%
df = pd.DataFrame({'values': model.feature_importances_, 'names': model.feature_names_in_ })
df.sort_values('values', ascending=False).head(2)
# Out:
#       values  names
# 12  0.415847  LSTAT
# 5   0.402682     RM

# %% [markdown]
# *Задание 4

# %% [markdown]
# В этом задании мы будем работать с датасетом, с которым мы уже знакомы по домашнему заданию по библиотеке Matplotlib, это датасет Credit Card Fraud Detection.Для этого датасета мы будем решать задачу классификации - будем определять,какие из транзакциции по кредитной карте являются мошенническими. Данный датасет сильно несбалансирован (так как случаи мошенничества относительно редки),так что применение метрики accuracy не принесет пользы и не поможет выбрать лучшую модель.Мы будем вычислять AUC, то есть площадь под кривой ROC.

# %% [markdown]
# Импортируйте из соответствующих модулей RandomForestClassifier, GridSearchCV и train_test_split.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Загрузите датасет creditcard.csv и создайте датафрейм df.

# %%
# Извиняюсь, но я не смог найти способ чтобы выгрузить файл такого размера в облако или запушить на гитхаб, ошибку выдавало
df = pd.read_csv('./data/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# С помощью метода value_counts с аргументом normalize=True убедитесь в том, что выборка несбалансирована.Используя метод info, проверьте, все ли столбцы содержат числовые данные и нет ли в них пропусков.Примените следующую настройку, чтобы можно было просматривать все столбцы датафрейма:
# pd.options.display.max_columns = 100.
# Просмотрите первые 10 строк датафрейма df.

# %%
pd.options.display.max_columns = 100
df.value_counts(normalize=True)
# Out:
# Time      V1          V2          V3         V4         V5         V6         V7          V8          V9         V10        V11        V12        V13        V14        V15        V16        V17        V18        V19        V20        V21         V22        V23        V24        V25        V26        V27        V28        Amount  Class
# 163152.0  -1.196037    1.585949    2.883976   3.378471   1.511706   3.717077   0.585362   -0.156001    0.122648   4.217934   1.385525  -0.709405  -0.256168  -1.564352   1.693218  -0.785210  -0.228008  -0.412833   0.234834   1.375790  -0.370294    0.524395  -0.355170  -0.869790  -0.133198   0.327804  -0.035702  -0.858197  7.56    0        0.000063
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10       V11       V12       V13       V14  \
# ...

# %% [markdown]
# Создайте датафрейм X из датафрейма df, исключив столбец Class.

# %%
X = df.loc[:, df.columns != 'Class']
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# Создайте объект Series под названием y из столбца Class.

# %%
y = df['Class']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %% [markdown]
# Разбейте X и y на тренировочный и тестовый наборы данных при помощи функции train_test_split, используя аргументы: test_size=0.3, random_state=100, stratify=y.
# У вас должны получиться объекты X_train, X_test, y_train и y_test.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %% [markdown]
# Просмотрите информацию о их форме.

# %%
X_train.shape
# Out:
# (199364, 30)

# %%
y_train.shape
# Out:
# (199364,)

# %%
X_test.shape
# Out:
# (85443, 30)

# %%
y_test.shape
# Out:
# (85443,)

# %% [markdown]
# Для поиска по сетке параметров задайте такие параметры:
# parameters = [{'n_estimators': [10, 15],
# 'max_features': np.arange(3, 5),
# 'max_depth': np.arange(4, 7)}]

# %%
parameters = [{'n_estimators': [10, 15], 'max_features': np.arange(3, 5), 'max_depth': np.arange(4, 7)}]

# %% [markdown]
# Создайте модель GridSearchCV со следующими аргументами:
# estimator=RandomForestClassifier(random_state=100),
# param_grid=parameters,
# scoring='roc_auc',
# cv=3.

# %%
model = GridSearchCV(estimator=RandomForestClassifier(random_state=100), param_grid=parameters, scoring='roc_auc', cv=3)

# %% [markdown]
# Обучите модель на тренировочном наборе данных (может занять несколько минут).

# %%
model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=100),
#              param_grid=[{'max_depth': array([4, 5, 6]),
#                           'max_features': array([3, 4]),
#                           'n_estimators': [10, 15]}],
#              scoring='roc_auc')

# %% [markdown]
# Просмотрите параметры лучшей модели с помощью атрибута best_params_.

# %%
model.best_params_
# Out:
# {'max_depth': 6, 'max_features': 3, 'n_estimators': 15}

# %% [markdown]
# Предскажите вероятности классов с помощью полученнной модели и метода predict_proba.

# %%
result = model.predict_proba(X_test)
# Out:
# array([0.00092917, 0.00029521, 0.00028215, ..., 0.00028215, 0.0006822 ,
#        0.01246098])

# %% [markdown]
# Из полученного результата (массив Numpy) выберите столбец с индексом 1 (вероятность класса 1) и запишите в массив y_pred_proba.

# %%
y_pred_proba = result[:, 1]
y_pred_proba
# Out:
# array([0.00092917, 0.00029521, 0.00028215, ..., 0.00028215, 0.0006822 ,
#        0.01246098])

# %% [markdown]
# Из модуля sklearn.metrics импортируйте метрику roc_auc_score.

# %%
from sklearn.metrics import roc_auc_score

# %% [markdown]
# Вычислите AUC на тестовых данных и сравните с результатом,полученным на тренировочных данных, используя в качестве аргументов массивы y_test и y_pred_proba.

# %%
print(f"Test {roc_auc_score(y_test, y_pred_proba)}")
# Out:
# Test 0.9462664156037156

# %% [markdown]
# Задание 5

# %% [markdown]
# В этом задании мы будем работать с датасетом, из встроенных датасетов sklearn.datasets load_digits. Изучите, что это за датасет, поймите, что это за задача (регрессия или классификация), изобразите первые 10 объектов из данных с помощью matplotlib.

# %%
from sklearn.datasets import load_digits
load_digits?
# Out:
# Signature: load_digits(*, n_class=10, return_X_y=False, as_frame=False)
# Docstring:
# Load and return the digits dataset (classification).
#
# Each datapoint is a 8x8 image of a digit.
#
# =================   ==============
# Classes                         10
# Samples per class             ~180
# Samples total                 1797
# Dimensionality                  64
# Features             integers 0-16
# =================   ==============
#
# Read more in the :ref:`User Guide <digits_dataset>`.
#
# Parameters
# ----------
# n_class : int, default=10
#     The number of classes to return. Between 0 and 10.
#
# return_X_y : bool, default=False
#     If True, returns ``(data, target)`` instead of a Bunch object.
#     See below for more information about the `data` and `target` object.
#
#     .. versionadded:: 0.18
#
# as_frame : bool, default=False
#     If True, the data is a pandas DataFrame including columns with
#     appropriate dtypes (numeric). The target is
# ...

# %% [markdown]
# Разбейте датасет на тренировочный и тестовый наборы данных.

# %%
X, y = load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Обучите наиболее понравившуюся вам модель машинного обучения и подберите лучшие гиперпараметры. Посчитайте подходящие метрики качества.

# %% [markdown]
# LinearRegression

# %%
lr = LinearRegression()
linear_model = lr.fit(X_train, y_train)
y_pred = linear_model.predict(X_test)
R2 = r2_score(y_test, y_pred)
print(f"For LinearRegression R2 scrore {R2}")
# Out:
# For LinearRegression R2 scrore 0.5817156631629645

# %% [markdown]
# RidgeCV

# %%
from sklearn.linear_model import RidgeCV
ridge_model = RidgeCV(alphas=[43.0123]).fit(X_train, y_train)
y_pred = ridge_model.predict(X_test)
R2 = r2_score(y_test, y_pred)
print(f"For RidgeCV R2 scrore {R2}")
# Out:
# For RidgeCV R2 scrore 0.5847734681377668

# %% [markdown]
# LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression().fit(X_train, y_train)
y_pred = logistic_model.predict(X_test)
R2 = r2_score(y_test, y_pred)
print(f"For LogisticRegression R2 scrore {R2}")
# Out:
# For LogisticRegression R2 scrore 0.9620012666244458

# %%
Perceptron

# %%
from sklearn.linear_model import Perceptron
perc_model = Perceptron(tol=0.7).fit(X_train, y_train)
y_pred = perc_model.predict(X_test)
R2 = r2_score(y_test, y_pred)
print(f"For Perceptron R2 scrore {R2}")
# Out:
# For Perceptron R2 scrore 0.9063933641236349

# %% [markdown]
# RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor(n_estimators=1000, max_depth=12, random_state=42).fit(X_train, y_train)
y_pred = random_forest_model.predict(X_test)
R2 = r2_score(y_test, y_pred)
print(f"For RandomForestRegressor R2 scrore {R2}")
# Out:
# For Perceptron R2 scrore 0.8384755323851197

# %%
pip install xgboost
# Out:
# ...
#      |████████████████████████████████| 173.6 MB 12 kB/s  eta 0:00:012
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost.sklearn import XGBRegressor
random_forest_model = XGBRegressor().fit(X_train, y_train)
y_pred = random_forest_model.predict(X_test)
R2 = r2_score(y_test, y_pred)
print(f"For XGBRegressor R2 scrore {R2}")
# Out:
# For XGBRegressor R2 scrore 0.8369699991005403

# %% [markdown]
# Задание 6

# %% [markdown]
# В этом задании вам нужно изучить, предобработать данные и обучить свою модель на предсказание стоимости недвижимости. Вам предстоит пройти весь путь работы над проектом в DS от начала до конца.

# %% [markdown]
# Возьмите данные с kaggle соревнования House Prices - Advanced Regression Techniques https://www.kaggle.com/c/house-prices-advanced-regression-techniques. Эта задача очень похожа на ту, над который мы работаем весь курс.

# %% [markdown]
# Можете продолжать работу в ноутбуке со всем ПЗ, либо перейти на kaggle и работать в публичном ноутбуке, но тогда обязательно прикрепите ссылку на ноутбук, когда полностью решите задачу.

# %% [markdown]
# План того, что должно присутствовать в вашем решении:

# %% [markdown]
# 1. Загрузка данных train.csv

# %%
train_df = pd.read_csv('https://res.cloudinary.com/dciwrzg9w/raw/upload/v1645661395/train_zjcfvg.csv')
test_df = pd.read_csv('https://res.cloudinary.com/dciwrzg9w/raw/upload/v1645661390/test_yrbmks.csv')
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# 2. EDA (Первичный визуальный анализ данных)

# %%
train_df.info()
train_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 292 kB 1.5 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
# Helpers

EMPTY_VALUE_COLOR = '#000099'
PRESENT_VALUE_COLOR = '#ffff00'
MEDIAN_COLUMNS = [
    'GarageYrBlt'
]
NA_MAPPING = {
    'MasVnrType': 'MasVnrType_None',
    'Alley': 'Alley_NA',
    'BsmtQual': 'BsmtQual_NA',
    'BsmtCond': 'BsmtCond_NA',
    'BsmtExposure': 'BsmtExposure_NA',
    'BsmtFinType1': 'BsmtFinType1_NA',
    'BsmtFinType2': 'BsmtFinType2_NA',
    'FireplaceQu': 'FireplaceQu_NA',
    'GarageType': 'GarageType_NA',
    'GarageFinish': 'GarageFinish_NA',
    'GarageQual': 'GarageQual_NA',
    'GarageCond': 'GarageCond_NA',
    'PoolQC': 'PoolQC_NA',
    'Fence': 'Fence_NA' 
}

# ['RoofMatl_Roll', 'GarageQual_Ex', 'RoofMatl_Membran', 'Exterior1st_ImStucc', 'PoolQC_Fa', 'RoofMatl_Metal', 'HouseStyle_2.5Fin', 'Heating_Floor', 'Electrical_No_Electrical', 'Exterior2nd_Other', 'Condition2_RRAe', 'Exterior1st_Stone', 'Condition2_RRAn', 'RoofMatl_ClyTile', 'Utilities_NoSeWa', 'Heating_OthW', 'Electrical_Mix', 'SalePrice', 'Condition2_RRNn']


CATEGIRICAL_COLUMNS_BY_ATTR = {
    'MSZoning': ['A', 'C', 'FV', 'I', 'RH', 'RL', 'RP', 'RM'],
    'Street': ['Pave', 'Grvl'],
    'Alley': ['Grvl', 'Pave', 'Alley_NA'],
    'LotShape': ['Reg', 'IR1', 'IR2', 'IR3'],
    'LandContour': ['Lvl', 'Bnk', 'HLS', 'Low'],
    'Utilities': ['AllPub', 'NoSewr', 'NoSeWa', 'ELO'],
    'LotConfig': ['Inside', 'Corner', 'CulDSac', 'FR2', 'FR3'],
    'LandSlope': ['Gtl', 'Mod', 'Sev'],
    'Neighborhood': ['Blmngtn', 'Blueste', 'BrDale', 'BrkSide', 'ClearCr', 'CollgCr', 'Crawfor', 'Edwards', 'Gilbert', 'IDOTRR', 'MeadowV', 'Mitchel', 'Names', 'NoRidge', 'NPkVill', 'NridgHt', 'NWAmes', 'OldTown', 'SWISU', 'Sawyer', 'SawyerW', 'Somerst', 'StoneBr', 'Timber', 'Veenker'],
    'Condition1': ['Artery', 'Feedr', 'Norm', 'RRNn', 'RRAn', 'PosN', 'PosA', 'RRNe', 'RRAe'],
    'Condition2': ['Artery', 'Feedr', 'Norm', 'RRNn', 'RRAn', 'PosN', 'PosA', 'RRNe', 'RRAe'],
    'BldgType': ['1Fam', '2FmCon', 'Duplx', 'TwnhsE', 'TwnhsI'],
    'HouseStyle': ['1Story', '1.5Fin', '1.5Unf', '2Story', '2.5Fin', '2.5Unf', 'SFoyer', 'SLvl'],
    'RoofStyle': ['Flat', 'Gable', 'Gambrel', 'Hip', 'Mansard', 'Shed'],
    'RoofMatl': ['ClyTile', 'CompShg', 'Membran', 'Metal', 'Roll', 'Tar&Grv', 'WdShake', 'WdShngl'],
    'Exterior1st': ['AsbShng', 'AsphShn', 'BrkComm', 'BrkFace', 'CBlock', 'CemntBd', 'HdBoard', 'ImStucc', 'MetalSd', 'Other', 'Plywood', 'PreCast', 'Stone', 'Stucco', 'VinylSd', 'Wd Sdng', 'WdShing'],
    'Exterior2nd': ['AsbShng', 'AsphShn', 'BrkComm', 'BrkFace', 'CBlock', 'CemntBd', 'HdBoard', 'ImStucc', 'MetalSd', 'Other', 'Plywood', 'PreCast', 'Stone', 'Stucco', 'VinylSd', 'Wd Sdng', 'WdShing'],
    'MasVnrType': ['BrkCmn', 'BrkFace', 'CBlock', 'MasVnrType_None', 'Stone'],
    'ExterQual': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
    'ExterCond': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
    'Foundation': ['BrkTil', 'CBlock', 'PConc', 'Slab', 'Stone', 'Wood'],
    'BsmtQual': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'BsmtQual_NA'],
    'BsmtCond': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'BsmtCond_NA'],
    'BsmtExposure': ['Gd', 'Av', 'Mn', 'No', 'BsmtExposure_NA'],
    'BsmtFinType1': ['GLQ', 'ALQ', 'BLQ', 'Rec', 'LwQ', 'Unf', 'BsmtFinType1_NA'],
    'BsmtFinType2': ['GLQ', 'ALQ', 'BLQ', 'Rec', 'LwQ', 'Unf', 'BsmtFinType2_NA'],
    'Heating': ['Floor', 'GasA', 'GasW', 'Grav', 'OthW', 'Wall'],
    'HeatingQC': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
    'CentralAir': ['Y', 'N'],
    'Electrical': ['SBrkr', 'FuseA', 'FuseF', 'FuseP', 'Mix'],
    'KitchenQual': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
    'Functional': ['Typ', 'Min1', 'Min2', 'Mod', 'Maj1', 'Maj2', 'Sev', 'Sal'],
    'FireplaceQu': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'FireplaceQu_NA'],
    'GarageType': ['2Types', 'Attchd', 'Basment', 'BuiltIn', 'CarPort', 'Detchd', 'GarageType_NA'],
    'GarageFinish': ['Fin', 'RFn', 'Unf', 'GarageFinish_NA'],
    'GarageQual': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'GarageQual_NA'],
    'GarageCond': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'GarageCond_NA'],
    'PavedDrive': ['Y', 'P', 'N'],
    'PoolQC': ['Ex', 'Gd', 'TA', 'Fa', 'PoolQC_NA'],
    'Fence': ['GdPrv', 'MnPrv', 'GdWo', 'MnWw', 'Fence_NA'],
    'SaleType': ['WD', 'CWD', 'VWD', 'New', 'COD', 'Con', 'ConLw', 'ConLI', 'ConLD', 'Oth'],
    'SaleCondition': ['Normal', 'Abnorml', 'AdjLand', 'Alloca', 'Family', 'Partial']
}


def draw_displot_for_null_values(dataframe, title):
    colours = [EMPTY_VALUE_COLOR, PRESENT_VALUE_COLOR] 
    sns.displot(data=dataframe.isna().melt(value_name="missing"), y="variable", hue="missing", multiple="fill", height=25).set(title=title)

# Check empty values for datasets
# draw_displot_for_null_values(test_df, title='Test Data Missing Values')

def fill_in_na(dataframe):
    dataframe.drop(columns=['MiscFeature'], inplace=True)
    
    numeric_columns = fetch_numeric_columns(dataframe)
    for column in numeric_columns:
        if column in MEDIAN_COLUMNS:
            dataframe[column].fillna(dataframe[column].median(), inplace=True)
        else:
            dataframe[column].fillna(0, inplace=True)
    
    categorical_columns = fetch_categorical_columns(dataframe)
    for column in categorical_columns:
        na_column = NA_MAPPING.get(column, f'No_{column}')
        dataframe[column].fillna(na_column, inplace=True)
    
    return dataframe


def fetch_categorical_columns(dataframe):
    categorical_columns = dataframe.select_dtypes(exclude=[np.number])
    categorical_columns = categorical_columns.columns.values
    return categorical_columns


def fetch_numeric_columns(dataframe):
    numeric_columns = dataframe.select_dtypes(include=[np.number])
    numeric_columns = numeric_columns.columns.values
    return numeric_columns


def transform_categorical_columns(dataframe):
    categorical_columns = fetch_categorical_columns(dataframe)
    dataframes_to_concat = []
    
    for column in categorical_columns:
        na_column = NA_MAPPING.get(column, f'No_{column}')
        categor_columns = set(CATEGIRICAL_COLUMNS_BY_ATTR[column] + [na_column])
        categorical_dataframe = pd.get_dummies(dataframe[column], prefix=column)
        additional_columns = list(set([f"{column}_{col}" for col in CATEGIRICAL_COLUMNS_BY_ATTR[column] + [na_column]]) - set(categorical_dataframe.columns.to_list()))
        additional_daraframe = pd.DataFrame(np.zeros((dataframe.shape[0], len(additional_columns))),columns=additional_columns)
        dataframe = pd.concat([dataframe, categorical_dataframe], axis=1)
        dataframes_to_concat.append(additional_daraframe)
        
    # for dataframe_to_concat in dataframes_to_concat:
    dataframe = pd.concat([dataframe, *dataframes_to_concat], axis=1)
        
    return dataframe


def remove_categotical_columns(dataframe):
    categorical_columns = fetch_categorical_columns(dataframe)
    dataframe.drop(columns=categorical_columns, inplace=True)
    return dataframe


def prepare_dataframe(dataframe):
    dataframe = fill_in_na(dataframe)
    dataframe = transform_categorical_columns(dataframe)
    dataframe = remove_categotical_columns(dataframe)
    dataframe = dataframe.reindex(sorted(dataframe.columns), axis=1)
    return dataframe


# CATEGIRICAL_COLUMNS_BY_ATTR.
# draw_displot_for_null_values(train_df, title='Train Data Missing Values')
# draw_displot_for_null_values(test_df, title='Test Data Missing Values')

# %% [markdown]
# 3. Предобработка данных (Пропуски, выбросы, масштабирование при необходимости)
# 4. Обучение модели
# 5. Проверка качества модели (Отложенная выборка, кросс-валидация)
# 6. Интерпретация результатов
# 7*. Сделать предсказания на test.csv и отправить предсказания в проверяющую систему kaggle
#
# Можете ознакомиться с готовыми решениями этого соревнования в публичных ноутбуках (https://www.kaggle.com/c/house-prices-advanced-regression-techniques/notebooks), здорово, если какие-то наработки возьмете к себе в работу, главное разобраться, зачем делается то или иное действие в ноутбуке и смело этим пользоваться.

# %%
# def prepare_dataframe(dataframe):
train_df = pd.read_csv('https://res.cloudinary.com/dciwrzg9w/raw/upload/v1645661395/train_zjcfvg.csv')
test_df = pd.read_csv('https://res.cloudinary.com/dciwrzg9w/raw/upload/v1645661390/test_yrbmks.csv')

# print(test_df.columns.size)
# print(list(set(train_df.columns.to_list()) - set(test_df.columns.to_list())))
# for col in list(set(train_df.columns.to_list()) - set(test_df.columns.to_list())):
    # test_df[col] = np.zeros((1459, 1))
# print(test_df.columns.size)

# Check NA values after preparing
# draw_displot_for_null_values(train_df, title='Train Data Missing Values')
# draw_displot_for_null_values(test_df, title='Test Data Missing Values')

# train_df.head()


y_train = train_df['SalePrice']
train_df.drop(columns=['SalePrice'], axis=1, inplace=True)
train_df = prepare_dataframe(train_df)
test_df = prepare_dataframe(test_df)
X_train = train_df
X_test = test_df

lr = LinearRegression()
linear_model = lr.fit(X_train, y_train)
print(linear_model.score(X_train, y_train))
y_pred_linear = linear_model.predict(X_test)
# 0.9331522537812306

from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor(n_estimators=1000, max_depth=16, random_state=42).fit(X_train, y_train)
print(random_forest_model.score(X_train, y_train))
y_pred_random_forest = random_forest_model.predict(X_test)
# 0.9809317053288221
# Out:
# 0.933172203539541
# 0.9813223571597349

# %%
pip install kaggle --upgrade
# Out:
# ...
#      |████████████████████████████████| 58 kB 762 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 76 kB 939 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 78 kB 1.7 MB/s eta 0:00:01
# ...
# Using legacy 'setup.py install' for kaggle, since package 'wheel' is not installed.
# ...
#     Running setup.py install for kaggle ... done
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
y_pred_df = pd.DataFrame({ 'Id': X_test['Id'], 'SalePrice': y_pred_linear })
y_pred_df.to_csv('./data/results/submission.csv', index=False)

# %%
kaggle competitions submit -c house-prices-advanced-regression-techniques -f "./data/results/submission.csv" -m "First try"
# Out:
#   Input In [1129]
#     kaggle competitions submit -c house-prices-advanced-regression-techniques -f "./data/results/submission.csv" -m "First try"
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# К сожалению не хватило времени доделать все задания, хоть и было интересно, надеюсь на итоговом проекте лучше вникнуть.

# %% [markdown]
# *Дополнительные задания:

# %% [markdown]
# 1). Загрузите датасет Wine из встроенных датасетов sklearn.datasets с помощью функции load_wine в переменную data.

# %% [markdown]
# 2). Полученный датасет не является датафреймом. Это структура данных, имеющая ключи аналогично словарю. Просмотрите тип данных этой структуры данных и создайте список data_keys, содержащий ее ключи.

# %% [markdown]
# 3). Просмотрите данные, описание и названия признаков в датасете. Описание нужно вывести в виде привычного, аккуратно оформленного текста, без обозначений переноса строки, но с самими переносами и т.д.

# %% [markdown]
# 4). Сколько классов содержит целевая переменная датасета? Выведите названия классов.

# %% [markdown]
# 5). На основе данных датасета (они содержатся в двумерном массиве Numpy) и названий признаков создайте датафрейм под названием X.

# %% [markdown]
# 6). Выясните размер датафрейма X и установитпе, имеются ли в нем пропущенные значения.

# %% [markdown]
# 7). Добавьте в датафрейм поле с классами вин в виде чисел, имеющих тип данных numpy.int64. Название поля - 'target'.

# %% [markdown]
# 8). Постройте матрицу корреляций для всех полей X. Дайте полученному датафрейму название X_corr.

# %% [markdown]
# 9). Создайте список high_corr из признаков, корреляция которых с полем target по абсолютному значению превышает 0.5 (причем, само поле target не должно входить в этот список).

# %% [markdown]
# 10). Удалите из датафрейма X поле с целевой переменной. Для всех признаков, названия которых содержатся в списке high_corr, вычислите квадрат их значений и добавьте в датафрейм X соответствующие поля с суффиксом '_2', добавленного к первоначальному названию признака. Итоговый датафрейм должен содержать все поля, которые, были в нем изначально, а также поля с признаками из списка high_corr, возведенными в квадрат. Выведите описание полей датафрейма X с помощью метода describe.

# %% [markdown]
# Импортируйте библиотеки pandas и numpy.

# %% [markdown]
# Загрузите "Boston House Prices dataset" из встроенных наборов данных библиотеки sklearn. Создайте датафреймы X и y из этих данных.

# %% [markdown]
# **Дополнительные задания по numpy и pandas

# %% [markdown]
# 1. Необходимо реализовать метод сортировки целых (int) элементов. Метод должен быть реализован без использования “готовых” методов ( sorted, np.sort() ).

# %% [markdown]
# 2. Вычисление метрик для мониторинга.
#  - суммарная выручка
#  - кол-во покупок
#  - средний чек
#  - среднее кол-во товаров в покупке

# %% [markdown]
# Дополнительно добавим возможность фильтровать данные по различным параметрам. Это может быть полезно чтобы посмотреть как меняются продажи в двух группах, или в какой-то отдельной категории товаров.

# %% [markdown]
# На вход функции будет подаваться датафрейм с данными о продажах, словарь с фильтрами и период, за который нужно посчитать метрики.

# %% [markdown]
# Функция должна вернуть датафрейм, в индексах которого будут все даты из указанного периода отсортированные по возрастанию, а столбцы - метрики ['revenue', 'number_purchases', 'average_check', 'average_number_items']. Формат данных столбцов - float, формат данных индекса - datetime64[ns].

# %% [markdown]
# Если в какие-то дни не было продаж, то нужно заполнить пропуск нулём.

# %%
import numpy as np
import pandas as pd
def calculate_sales_metrics(df, cost_name, date_name, sale_id_name, period, filters=None):
   """Вычисляет метрики по продажам.
   df - pd.DataFrame, датафрейм с данными. Пример
       pd.DataFrame(
           [[820, '2021-04-03', 1, 213]],
           columns=['cost', 'date', 'sale_id', 'shop_id']
       )
   cost_name - str, название столбца с стоимостью товара
   date_name - str, название столбца с датой покупки
   sale_id_name - str, название столбца с идентификатором покупки (в одной покупке может быть несколько товаров)
   period - dict, словарь с датами начала и конца периода пилота.
       Пример, {'begin': '2020-01-01', 'end': '2020-01-08'}.
       Дата начала периода входит в полуинтервал, а дата окончания нет,
       то есть '2020-01-01' <= date < '2020-01-08'.
   filters - dict, словарь с фильтрами. Ключ - название поля, по которому фильтруем, значение - список значений,
       которые нужно оставить. Например, {'user_id': [111, 123, 943]}.
       Если None, то фильтровать не нужно.
   return - pd.DataFrame, в индексах все даты из указанного периода отсортированные по возрастанию,
       столбцы - метрики ['revenue', 'number_purchases', 'average_check', 'average_number_items'].
       Формат данных столбцов - float, формат данных индекса - datetime64[ns].
   """
   # YOUR_CODE_HERE
